# %% [markdown]
# # PySpark
# * https://spark.apache.org/docs/latest/api/python/getting_started/index.html
#
# actions:
# - https://github.com/jargonzhou/application-store/tree/main/data-engineering/spark

# %%
# important: choose .venv Python kernel

# !pip uninstall -y pyspark
# !pip install pyspark==3.5.8
# Out:
# Requirement already satisfied: pyspark==3.5.8 in d:\software\miniconda3\lib\site-packages (3.5.8)
# Requirement already satisfied: py4j<0.10.9.10,>=0.10.9.7 in d:\software\miniconda3\lib\site-packages (from pyspark==3.5.8) (0.10.9.7)

# %%
# Spark SQL
# !pip install "pyspark[sql]"
# pandas API on Spark
# to plot your data, you can install plotly together.
# !pip install "pyspark[pandas_on_spark]" plotly  
# Spark Connect
# !pip install "pyspark[connect]"
# Python Spark Connect Client
#!pip install pyspark-client

# MLlib
# !pip install "pyspark[mllib]"
# MLlib DataFrame-based API
# !pip install "pyspark[ml]"

# Declarative Pipelines
# !pip install "pyspark[pipelines]"
# Out:
# Requirement already satisfied: pyspark[sql] in d:\software\miniconda3\lib\site-packages (3.5.8)
# Requirement already satisfied: py4j<0.10.9.10,>=0.10.9.7 in d:\software\miniconda3\lib\site-packages (from pyspark[sql]) (0.10.9.7)
# Requirement already satisfied: pandas>=1.0.5 in d:\software\miniconda3\lib\site-packages (from pyspark[sql]) (2.3.3)
# Requirement already satisfied: pyarrow>=4.0.0 in d:\software\miniconda3\lib\site-packages (from pyspark[sql]) (19.0.1)
# Requirement already satisfied: numpy<2,>=1.15 in d:\software\miniconda3\lib\site-packages (from pyspark[sql]) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\software\miniconda3\lib\site-packages (from pandas>=1.0.5->pyspark[sql]) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in d:\software\miniconda3\lib\site-packages (from pandas>=1.0.5->pyspark[sql]) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in d:\software\miniconda3\lib\site-packages (from pandas>=1.0.5->pyspark[sql]) (2026.1)
# Requirement already satisfied: six>=1.5 in d:\software\miniconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.0.5->pyspark[sql]) (1.16.0)
# Requirement already satisfied: plotly in d:\software\miniconda3\lib\site-packages (6.0.1)
# Requirement already satisfied: pyspark[pandas_on_spark] in d:\software\miniconda3\lib\site-packages (3.5.8)
# Requirement already satisfied: py4j<0.10.9.10,>=0.10.9.7 in d:\software\miniconda3\lib\site-packages (from pyspark[pandas_on_spark]) (0.10.9.7)
# Requirement already satisfied: pandas>=1.0.5 in d:\software\miniconda3\lib\site-packages (from pyspark[pandas_on_spark]) (2.3.3)
# Requirement already satisfied: pyarrow>=4.0.0 in d:\software\miniconda3\lib\site-packages (from pyspark[pandas_on_spark]) (19.0.1)
# Requirement already satisfied: numpy<2,>=1.15 in d:\software\miniconda3\lib\site-packages (from pyspark[pandas_on_spark]) (1.26.4)
# Requirement already satisfied: narwhals>=1.15.1 in d:\software\miniconda3\lib\site-packages (from plotly) (1.31.0)
# Requirement already satisfied: packaging in d:\software\miniconda3\lib\site-packages (from plotly) (26.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\software\miniconda3\lib\site-packages (from pandas>=1.0.5->pyspark[pandas_on_spark]) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in d:\software\miniconda3\lib\site-packages (from pandas>=1.0.5->pyspark[pandas_on_spark]) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in d:\software\miniconda3\lib\site-packages (from pandas>=1.0.5->pyspark[pandas_on_spark]) (2026.1)
# Requirement already satisfied: six>=1.5 in d:\software\miniconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.0.5->pyspark[pandas_on_spark]) (1.16.0)
# Requirement already satisfied: pyspark[connect] in d:\software\miniconda3\lib\site-packages (3.5.8)
# Requirement already satisfied: py4j<0.10.9.10,>=0.10.9.7 in d:\software\miniconda3\lib\site-packages (from pyspark[connect]) (0.10.9.7)
# Requirement already satisfied: pandas>=1.0.5 in d:\software\miniconda3\lib\site-packages (from pyspark[connect]) (2.3.3)
# Requirement already satisfied: pyarrow>=4.0.0 in d:\software\miniconda3\lib\site-packages (from pyspark[connect]) (19.0.1)
# Requirement already satisfied: grpcio>=1.56.0 in d:\software\miniconda3\lib\site-packages (from pyspark[connect]) (1.80.0)
# Requirement already satisfied: grpcio-status>=1.56.0 in d:\software\miniconda3\lib\site-packages (from pyspark[connect]) (1.80.0)
# Requirement already satisfied: googleapis-common-protos>=1.56.4 in d:\software\miniconda3\lib\site-packages (from pyspark[connect]) (1.74.0)
# Requirement already satisfied: numpy<2,>=1.15 in d:\software\miniconda3\lib\site-packages (from pyspark[connect]) (1.26.4)
# Requirement already satisfied: protobuf<8.0.0,>=4.25.8 in d:\software\miniconda3\lib\site-packages (from googleapis-common-protos>=1.56.4->pyspark[connect]) (6.33.5)
# Requirement already satisfied: typing-extensions~=4.12 in d:\software\miniconda3\lib\site-packages (from grpcio>=1.56.0->pyspark[connect]) (4.15.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\software\miniconda3\lib\site-packages (from pandas>=1.0.5->pyspark[connect]) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in d:\software\miniconda3\lib\site-packages (from pandas>=1.0.5->pyspark[connect]) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in d:\software\miniconda3\lib\site-packages (from pandas>=1.0.5->pyspark[connect]) (2026.1)
# Requirement already satisfied: six>=1.5 in d:\software\miniconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.0.5->pyspark[connect]) (1.16.0)
# Requirement already satisfied: pyspark[mllib] in d:\software\miniconda3\lib\site-packages (3.5.8)
# Requirement already satisfied: py4j<0.10.9.10,>=0.10.9.7 in d:\software\miniconda3\lib\site-packages (from pyspark[mllib]) (0.10.9.7)
# Requirement already satisfied: numpy<2,>=1.15 in d:\software\miniconda3\lib\site-packages (from pyspark[mllib]) (1.26.4)
# Requirement already satisfied: pyspark[ml] in d:\software\miniconda3\lib\site-packages (3.5.8)
# Requirement already satisfied: py4j<0.10.9.10,>=0.10.9.7 in d:\software\miniconda3\lib\site-packages (from pyspark[ml]) (0.10.9.7)
# Requirement already satisfied: numpy<2,>=1.15 in d:\software\miniconda3\lib\site-packages (from pyspark[ml]) (1.26.4)
# Requirement already satisfied: pyspark[pipelines] in d:\software\miniconda3\lib\site-packages (3.5.8)
# Requirement already satisfied: py4j<0.10.9.10,>=0.10.9.7 in d:\software\miniconda3\lib\site-packages (from pyspark[pipelines]) (0.10.9.7)
# WARNING: pyspark 3.5.8 does not provide the extra 'pipelines'

# %%
import pyspark
pyspark.__version__
# Out:
# '3.5.8'

# %%
import socket

hostname = socket.gethostname()
IPAddr = socket.gethostbyname(hostname)

print("Your Computer Name is:", hostname)
print("Your Computer IP Address is:", IPAddr)
# Out:
# Your Computer Name is: 2cce40987363
# Your Computer IP Address is: 172.18.0.4

# %% [markdown]
# # DataFrame

# %%
from pyspark.conf import SparkConf
from pyspark.sql import SparkSession

# important: spark.driver.host
# conf = SparkConf().setAppName("example").setMaster("spark://127.0.0.1:7077").set('spark.driver.host', IPAddr)
conf = SparkConf().setAppName("example").setMaster("spark://spark-master:7077").set('spark.driver.host', IPAddr) # in same Docker network
spark = SparkSession.builder.config(conf=conf).getOrCreate()
spark.version
# Out:
# '3.5.8'

# %%
spark.conf.get('spark.driver.host')
# Out:
# '10.50.1.41'

# %%
spark.sql("SELECT version()").show()
# Out:
# [Stage 0:>                                                          (0 + 1) / 1]
# +--------------------+
# |           version()|
# +--------------------+
# |3.5.8 5a48a37b2db...|
# +--------------------+

# %%
from datetime import datetime, date
import pandas as pd
from pyspark.sql import Row

# from a list of rows
df = spark.createDataFrame([
    Row(a=1, b=2., c='string1', d=date(2000, 1, 1), e=datetime(2000, 1, 1, 12, 0)),
    Row(a=2, b=3., c='string2', d=date(2000, 2, 1), e=datetime(2000, 1, 2, 12, 0)),
    Row(a=4, b=5., c='string3', d=date(2000, 3, 1), e=datetime(2000, 1, 3, 12, 0))
])
df.show()
# Out:
# [Stage 1:>                                                          (0 + 1) / 1]
# +---+---+-------+----------+-------------------+
# |  a|  b|      c|         d|                  e|
# +---+---+-------+----------+-------------------+
# |  1|2.0|string1|2000-01-01|2000-01-01 12:00:00|
# |  2|3.0|string2|2000-02-01|2000-01-02 12:00:00|
# |  4|5.0|string3|2000-03-01|2000-01-03 12:00:00|
# +---+---+-------+----------+-------------------+

# %%
# with explicit scheme
df = spark.createDataFrame([
    (1, 2., 'string1', date(2000, 1, 1), datetime(2000, 1, 1, 12, 0)),
    (2, 3., 'string2', date(2000, 2, 1), datetime(2000, 1, 2, 12, 0)),
    (3, 4., 'string3', date(2000, 3, 1), datetime(2000, 1, 3, 12, 0))
], schema='a long, b double, c string, d date, e timestamp')
df
# Out:
# DataFrame[a: bigint, b: double, c: string, d: date, e: timestamp]

# %%
# from pandas DataFrame
pandas_df = pd.DataFrame({
    'a': [1, 2, 3],
    'b': [2., 3., 4.],
    'c': ['string1', 'string2', 'string3'],
    'd': [date(2000, 1, 1), date(2000, 2, 1), date(2000, 3, 1)],
    'e': [datetime(2000, 1, 1, 12, 0), datetime(2000, 1, 2, 12, 0), datetime(2000, 1, 3, 12, 0)]
})
df = spark.createDataFrame(pandas_df)
df
# Out:
# DataFrame[a: bigint, b: double, c: string, d: date, e: timestamp]

# %%
df.show()
df.printSchema()
# Out:
# +---+---+-------+----------+-------------------+
# |  a|  b|      c|         d|                  e|
# +---+---+-------+----------+-------------------+
# |  1|2.0|string1|2000-01-01|2000-01-01 12:00:00|
# |  2|3.0|string2|2000-02-01|2000-01-02 12:00:00|
# |  3|4.0|string3|2000-03-01|2000-01-03 12:00:00|
# +---+---+-------+----------+-------------------+
#
# root
#  |-- a: long (nullable = true)
#  |-- b: double (nullable = true)
#  |-- c: string (nullable = true)
#  |-- d: date (nullable = true)
#  |-- e: timestamp (nullable = true)
# 26/04/20 09:16:45 ERROR TaskSchedulerImpl: Lost executor 0 on 172.18.0.5: Command exited with code 143
# 26/04/20 09:16:46 WARN StandaloneAppClient$ClientEndpoint: Connection to 172.18.0.3:7077 failed; waiting for master to reconnect...
# 26/04/20 09:16:46 WARN StandaloneSchedulerBackend: Disconnected from Spark cluster! Waiting for reconnection...

# %%
# %env

# 'SPARK_AUTH_SOCKET_TIMEOUT': '15',
#  'SPARK_BUFFER_SIZE': '65536'

# %%
spark.stop()

# %% [markdown]
# # Spark Connect

# %% [markdown]
# ```shell
# # example: in master
# /opt/bitnami/spark$ sbin/start-connect-server.sh --packages org.apache.spark:spark-connect_2.12:3.5.5
# starting org.apache.spark.sql.connect.service.SparkConnectServer, logging to /opt/bitnami/spark/logs/spark--org.apache.spark.sql.connect.service.SparkConnectServer-1-724dbdc1d558.out
# ```

# %%
# %env SPARK_REMOTE="sc://localhost:15002"
# Out:
# env: SPARK_REMOTE="sc://localhost:15002"

# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder \
  .appName('spike-connect-app') \
  .remote("sc://localhost:15002") \
  .getOrCreate() #\
  # .config("spark.sql.session.localRelationChunkSizeRows", 10000)
spark.version
# Out:
# '3.5.8'

# %%
from datetime import datetime, date

df = spark.createDataFrame([
    (1, 2., 'string1', date(2000, 1, 1), datetime(2000, 1, 1, 12, 0)),
    (2, 3., 'string2', date(2000, 2, 1), datetime(2000, 1, 2, 12, 0)),
    (3, 4., 'string3', date(2000, 3, 1), datetime(2000, 1, 3, 12, 0))
], schema='a long, b double, c string, d date, e timestamp')
df.show()
# Out:
# +---+---+-------+----------+-------------------+
# |  a|  b|      c|         d|                  e|
# +---+---+-------+----------+-------------------+
# |  1|2.0|string1|2000-01-01|2000-01-01 04:00:00|
# |  2|3.0|string2|2000-02-01|2000-01-02 04:00:00|
# |  3|4.0|string3|2000-03-01|2000-01-03 04:00:00|
# +---+---+-------+----------+-------------------+

# %%
# %env

#  'SPARK_AUTH_SOCKET_TIMEOUT': '15',
#  'SPARK_BUFFER_SIZE': '65536',
#  'SPARK_CONNECT_MODE_ENABLED': '1'

# %%
spark.stop()

# %%
# important: clean the environment
import os
if 'SPARK_CONNECT_MODE_ENABLED' in os.environ:
  del os.environ['SPARK_CONNECT_MODE_ENABLED']

# %%
SparkSession.getActiveSession()

# %% [markdown]
# # Pandas API

# %%
# %env PYARROW_IGNORE_TIMEZONE=1
# Out:
# env: PYARROW_IGNORE_TIMEZONE=1

# %%
import pandas as pd
import numpy as np
import pyspark.pandas as ps

from pyspark.conf import SparkConf
from pyspark.sql import SparkSession


# important: spark.driver.host
conf = SparkConf().setAppName("example").setMaster("spark://127.0.0.1:7077").set('spark.driver.host', IPAddr)

spark = SparkSession.builder.config(conf=conf).getOrCreate()

# %%
ps.Series([1, 3, 5, np.nan, 6, 8])
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %%
ps.DataFrame(
    {'a': [1, 2, 3, 4, 5, 6],
     'b': [100, 200, 300, 400, 500, 600],
     'c': ["one", "two", "three", "four", "five", "six"]},
    index=[10, 20, 30, 40, 50, 60])
# Out:
#     a    b      c
# 10  1  100    one
# 20  2  200    two
# 30  3  300  three
# 40  4  400   four
# 50  5  500   five
# 60  6  600    six

# %%
spark.stop()

# %% [markdown]
# # I Wanna to do ...

# %% [markdown]
# - read MySQL Table
# - read Kafka
# - read Redis
# - read Elasticsearch

# %% [markdown]
# ## MySQL

# %%
# !pip install findspark

# %%
# example
# https://github.com/apache/spark/blob/master/examples/src/main/python/sql/datasource.py#L380
#
# datasource options
# https://spark.apache.org/docs/latest/sql-data-sources-jdbc.html#data-source-option

# import findspark
# findspark.init()
from pyspark.sql import SparkSession

# .config('spark.jars', "C:/Users/zhouj/.m2/repository/com/mysql/mysql-connector-j/8.0.32/mysql-connector-j-8.0.32.jar") \
    # .config('spark.driver.extraClassPath', "/opt/bitnami/spark/jars/mysql-connector-j-8.0.32.jar") \
spark = SparkSession.builder \
    .appName('spike-mysql-app') \
    .master("spark://localhost:7077") \
    .config('spark.jars', "/opt/bitnami/spark/jars/mysql-connector-j-8.0.32.jar") \
    .config('spark.driver.extraClassPath', "mysql-connector-j-8.0.32.jar") \
    .getOrCreate()

# %% [markdown]
# ### read

# %%
# sql.SparkSession.read
# https://spark.apache.org/docs/latest/api/python/reference/pyspark.sql/api/pyspark.sql.SparkSession.read.html
jdbcDF = spark.read \
    .format("jdbc") \
    .option("url", "jdbc:mysql://192.168.3.178:3306/devops") \
    .option("driver", "com.mysql.cj.jdbc.Driver") \
    .option("dbtable", "users") \
    .option("user", "root") \
    .option("password", "change_me") \
    .load()
jdbcDF.show()

spark.read \
    .jdbc(url="jdbc:mysql://192.168.3.178:3306/devops", 
        table='users', 
        predicates=['id > 2'],
        properties = {'user': 'root', 'password': 'change_me'}) \
    .show()
# Out:
# +---+----------------+--------+
# | id|           email|password|
# +---+----------------+--------+
# |  1|xxx1@example.com|    pwd1|
# |  2|xxx2@example.com|    pwd2|
# |  3|xxx3@example.com|    pwd3|
# |  4|xxx4@example.com|    pwd4|
# +---+----------------+--------+
#
# +---+----------------+--------+
# | id|           email|password|
# +---+----------------+--------+
# |  3|xxx3@example.com|    pwd3|
# |  4|xxx4@example.com|    pwd4|
# +---+----------------+--------+

# %%
# DataFrame上过滤
jdbcDF.filter(jdbcDF['id'] > 2).show()
# Out:
# +---+----------------+--------+
# | id|           email|password|
# +---+----------------+--------+
# |  3|xxx3@example.com|    pwd3|
# |  4|xxx4@example.com|    pwd4|
# +---+----------------+--------+

# %% [markdown]
# ### write

# %%
from pyspark.sql import Row

# DataFrame.write
# https://spark.apache.org/docs/latest/api/python/reference/pyspark.sql/api/pyspark.sql.DataFrame.write.html#pyspark.sql.DataFrame.write
df = spark.createDataFrame([
    Row(id=4, email='xxx@example.com', password='pwd')
])

# 追加: 存在主键重复
df.write \
    .format("jdbc") \
    .option("url", "jdbc:mysql://192.168.3.178:3306/devops") \
    .option("driver", "com.mysql.cj.jdbc.Driver") \
    .option("dbtable", "users") \
    .option("user", "root") \
    .option("password", "change_me") \
    .mode('append') \
    .save()

# %%
df = spark.createDataFrame([
  Row(id=1, email='xxx1@example.com', password='pwd1'),
  Row(id=2, email='xxx2@example.com', password='pwd2'),
  Row(id=3, email='xxx3@example.com', password='pwd3'),
  Row(id=4, email='xxx4@example.com', password='pwd4')
])

df.write \
  .jdbc(url="jdbc:mysql://192.168.3.178:3306/devops", 
        table='users', 
        # mode='ignore', 
        mode='overwrite', # 全部覆盖
        # mode='append', # 追加: 存在主键重复
        properties = {'user': 'root', 'password': 'change_me'})

# %%
spark.read \
    .jdbc(url="jdbc:mysql://192.168.3.178:3306/devops", 
        table='users', 
        properties = {'user': 'root', 'password': 'change_me'}) \
    .show()
# Out:
# +---+----------------+--------+
# | id|           email|password|
# +---+----------------+--------+
# |  1|xxx1@example.com|    pwd1|
# |  2|xxx2@example.com|    pwd2|
# |  3|xxx3@example.com|    pwd3|
# |  4|xxx4@example.com|    pwd4|
# +---+----------------+--------+

# %% [markdown]
# ### sql

# %%
# %env HADOOP_HOME=.
# Out:
# env: HADOOP_HOME=.

# %%
# sql.SparkSession.sql
# https://spark.apache.org/docs/latest/api/python/reference/pyspark.sql/api/pyspark.sql.SparkSession.sql.html
#
# SQL syntax
# https://spark.apache.org/docs/latest/sql-ref-syntax.html

# Why we need this???
# : java.lang.UnsatisfiedLinkError: 'boolean org.apache.hadoop.io.nativeio.NativeIO$Windows.access0(java.lang.String, int)'
# https://sparkbyexamples.com/spark/spark-hadoop-exception-in-thread-main-java-lang-unsatisfiedlinkerror-org-apache-hadoop-io-nativeio-nativeiowindows-access0ljava-lang-stringiz/

# spark.sql("""
# CREATE TABLE s_users(id BIGINT, email STRING, password STRING) USING JDBC
# OPTIONS (
#     'url'='jdbc:mysql://192.168.3.178:3306/devops',
#     'driver'='com.mysql.cj.jdbc.Driver',
#     'dbtable'='users',
#     'user'='root',
#     'password'='change_me' 
# )
# COMMENT 'table from devops.users'
# """).show()

# play in spark-sql
# 
# spark-sql (default)> CREATE TABLE s_users(id BIGINT, email STRING, password STRING) USING JDBC
#                    > OPTIONS (
#                    >     'url'='jdbc:mysql://192.168.3.178:3306/devops',
#                    >     'driver'='com.mysql.cj.jdbc.Driver',
#                    >     'dbtable'='users',
#                    >     'user'='root',
#                    >     'password'='change_me' 
#                    > )
#                    > COMMENT 'table from devops.users';

# spark-sql (default)> select * from s_users;
# 1       xxx1@example.com        pwd1
# 2       xxx2@example.com        pwd2
# 3       xxx3@example.com        pwd3
# 4       xxx4@example.com        pwd4
# Time taken: 1.079 seconds, Fetched 4 row(s)

# %%
# spark.sql("SELECT * FROM s_users").show()

# %%
spark.stop()

# %% [markdown]
# ## Redis
# * https://github.com/RedisLabs/spark-redis/blob/master/doc/python.md

# %% [markdown]
# ## Machine Learning
# * https://www.machinelearningplus.com/pyspark/what-is-sparksession/
